# %%
import pandas as pd

# %%
def dataResolveStudio(fileName):
    file = "./Data/Raw/{}.xlsx".format(fileName)
    df = pd.read_excel(file)
    return df.head()

# %% [markdown]
# ## Analitica

# %%
analiticaData = dataResolveStudio("Analitica")
# Out:
#             Marca               Campaña  conversion                     Fecha  \
# 0           Pepsi  Lo que te hace falta          14  2019-06-09T00:00:00.000Z
# 1        Cocacola  Lo que te hace falta          62  2019-06-09T00:01:00.000Z
# 2  Aceite de coco              La mejor          62  2019-06-09T00:01:00.000Z
# 3           Pepsi  Lo que te hace falta          87  2019-06-09T00:02:00.000Z
# 4           Pepsi              La mejor           7  2019-06-09T00:03:00.000Z
#
#         Medio    Fuente
# 0       Radio       RCN
# 1  Televisión  Facebook
# 2    Internet       RCN
# 3    Internet       RCN
# 4    Internet       RCN

# %% [markdown]
# ## Conversiones

# %%
dataResolveStudio("Conversiones")
# Out:
#                 Campaña  Grupo  Asistente    Creatividad  \
# 0              Toma Más      5          1     Azucaradas
# 1              La mejor      4          1     Azucaradas
# 2              Toma Más      4          2   Innigualable
# 3  Lo que te hace falta      1          2   Innigualable
# 4              La mejor      2          4  Te lo mereces
#
#    Número objetivo de conversión                     Fecha  Medio  source  \
# 0                            413  2019-06-01T00:00:00.000Z      3       2
# 1                            303  2019-06-01T00:00:00.000Z      3       3
# 2                            433  2019-06-01T00:00:00.000Z      3       5
# 3                            152  2019-06-01T00:00:00.000Z      1       4
# 4                            389  2019-06-01T00:00:00.000Z      3       2
#
#    Total de conversiones
# 0                    268
# 1                    168
# 2                    114
# 3                    206
# 4                    198

# %% [markdown]
# ## Demografía

# %%
dataResolveStudio("Demografía")
# Out:
#   browser  Ciudad                     Fecha   device    ID Sistema Operativo  \
# 0  Chrome  Guaspí  2019-06-01T00:00:00.000Z  desktop  1136           Windows
# 1  Chrome  Guaspí  2019-06-01T00:01:00.000Z  desktop  1224           Windows
# 2  Chrome  Cereté  2019-06-01T00:01:00.000Z   mobile  1630           Android
# 3  Chrome  Dallas  2019-06-01T00:02:00.000Z   mobile  1133           Android
# 4  Chrome   Tunja  2019-06-01T00:03:00.000Z   mobile  1585           Android
#
#    Sesion   Duracion  Tiempo en pagina
# 0        6        51                58
# 1        9        49                36
# 2        2        56                31
# 3        4        52                27
# 4        9        31                57

# %% [markdown]
# ## Interacciones

# %%
dataResolveStudio("Interacciones")
# Out:
#    Promedio de duración  Tiempo en página    ID      Fecha  hour  minute
# 0                    27                41  1864 2019-06-05     0      23
# 1                    27                53  1215 2019-06-05     0      26
# 2                    14                39  1933 2019-06-05     0       5
# 3                    47                57  1605 2019-06-05     0       7
# 4                    24                53  1626 2019-06-05     0       7

# %% [markdown]
# ## Parrilla

# %%
dataResolveStudio("Parrilla")
# Out:
#    channel                  end_date Formato  inversion      medium  rating  \
# 0  Caracol  2019-06-01T09:55:16.000Z   Corto     648723       Radio       3
# 1  Caracol  2019-06-01T10:29:44.000Z   Largo     949072  Televisión       8
# 2  Caracol  2019-06-01T14:44:27.000Z   Largo     911123    Internet       2
# 3  Caracol  2019-06-01T19:20:52.000Z   Largo     922200    Internet       2
# 4  Caracol  2019-06-02T09:54:08.000Z   Corto     733026    Internet       3
#
#     reference                start_date
# 0      Tomala  2019-06-01T09:54:56.000Z
# 1      Tomala  2019-06-01T10:29:24.000Z
# 2  Disfrutala  2019-06-01T14:44:07.000Z
# 3      Tomala  2019-06-01T19:20:32.000Z
# 4  Disfrutala  2019-06-02T09:53:48.000Z
